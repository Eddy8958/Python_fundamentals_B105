# %%
INTRODUCTION TO LIST DATA TYPES:

# %%
definitition - A list is a collection of items decalred in particular order.
    classified - it is classified as mutable data type
how to declare the list datatype ------>[  ismein ]

# %%
students = ['hamza', 'manish', 'soban', 'meri', 'jaan', 'faiza']  # indexing 0,1,2,3,4,5

# %%
print(students)
# Out:
# ['hamza', 'manish', 'soban', 'meri', 'jaan', 'faiza']

# %%
type(students)
# Out:
# list

# %%
#i wnat to access faiza name in outuput

# %%
print(students[5]) # yaha pe indexing ka use krke accesse krliya naam
# Out:
# faiza

# %%
how to add new elements to the list
how to modified the elements in the list
how to delete the elements in the list

# %%
# req ; i want to add bilal in the above table...

# %%
students.append('bilal')

# %% [raw]
#  # req : i want to add hamza in the above list

# %%
students.append('hamzaa')

# %%
# req : i wnat to add masooda at 2nd index..?

# %%
students.insert(2,'massoda')

# %%
interview ques - what is the diff bw apepend and insert method in a list datatype can you explain..?

# %%
# req : i want to modified manish nmae to asif    # this is modification in list

# %%
students[1] = 'faiza'

# %%
3 req : i want to delete  meri name

# %%
del students[4]

# %%
print(students)
