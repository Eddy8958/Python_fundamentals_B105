# %%
INTRODUCTION TO PYTHON FUNDAMENTALS

# %%
understing the variables in python:

# %%
a = 2
b = 4

# %%
c = a+b
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c = a+b
#       2 print(c)
#
# NameError: name 'a' is not defined

# %%
Rules for declaring the variales in python :
# Out:
#   Cell In[3], line 1
#     Rules for declaring the variales in python :
#           ^
# SyntaxError: invalid syntax

# %%
Rule - 1 : no nameSpcae while declaring the variable name

# %%
firs name = 'hamza'
print(first name)
# Out:
#   Cell In[4], line 1
#     firs name = 'hamza'
#          ^
# SyntaxError: invalid syntax

# %%
firstname = 'hamza'
print(firstname)
# Out:
# hamza

# %%
rule 2 : a varibale name should not start with a number **

# %%
1name = 'hamza'
print(1name)
# Out:
#   Cell In[7], line 1
#     1name = 'hamza'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'eddy'
print(name1)
# Out:
# eddy

# %%
Rule 3 : a varible name should not contain any special characters
@#$%^&()

# %%
test@ = 'swati'
print(test@)
# Out:
#   Cell In[9], line 1
#     test@ = 'swati'
#           ^
# SyntaxError: invalid syntax

# %%
INTRODUCTION TO DATATYPES IN PYTHON:
       1. strings -----> str
       2. numbers ------> integers --- (int) and float(decimal ---- 0.1,0.1)
       3. list
       4. tuple
       5. dictionary ------> dict

# %%
   classification of datatypes :
    Broadly datatypes are classified in to 2 categories :
    1. mutable -----> which can edit/alter  ---- flexible i nature
    2. imutabe -----> which we cannot edit/ alter  - fixed in nature

# %%
Introduction to strig datatype :

# %%
definition of string : a string is nothing but a seqence of characters written in qutes.
    classsification : it is classified as an inmutable datatype
how do you declear the string 
1. approch - 1 : unsing single quote

2. approch -2 : using double quote

# %%
name = 'hamza'  # single quote
print(name)

# %%
name2 = "hamza"  # double quote 
print(name2)
# Out:
# hamza

# %%
INTRODUCTION TO STRING METHODS :

# %%
type(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 type(name)
#
# NameError: name 'name' is not defined

# %%
type(name2)
# Out:
# str

# %%
fullname = 'hMza'
print(fullname)
# Out:
# hMza

# %%
# req : how to correct the format

# %%
print(fullname.title())
# Out:
# Hmza

# %%
# req : i want full name in capital
