# %%
B - 105 ------> participants

# %%
INTRODUCTION TO FSTRING :
# Out:
#   Cell In[1], line 1
#     INTRODUCTION TO FSTRING :
#                  ^
# SyntaxError: invalid syntax

# %%
firstname = 'syed'
lastname = 'ali'

# %%
# req i want full name 
# general syntax of f string...?

# %%
message = f"custom message {place_holder_1} {place_holder_2} {placeholder_n}"

# %%
fullname = f"{firstname} {lastname}"

print(fullname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fullname = f"{firstname} {lastname}"
#       2
#       3 print(fullname)
#
# NameError: name 'firstname' is not defined

# %%
print(fullname.title())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(fullname.title())
#
# NameError: name 'fullname' is not defined

# %%
INTRODUCTION TO WHITESPACES :

# %%
print("fav_prog:pythonJavaC++swiftjavascript")
# Out:
# fav_prog:pythonJavaC++swiftjavascript

# %%
print("fav_prog:\n\tpython\n\tJava\n\tC++\n\tswift\n\tjavascript")
# Out:
# fav_prog:
# 	python
# 	Java
# 	C++
# 	swift
# 	javascript

# %%
print("fav_prog:python\nJava\nC++\nswift\njavascript")   # tab spaces
# Out:
# fav_prog:python
# Java
# C++
# swift
# javascript

# %%
eliminating whitespaces :

# %%
name = " python"
print(name)
# Out:
#  python

# %%
name2 = 'python '
print(name2)
# Out:
# python

# %%
name3 = 'python'
print(name3)
# Out:
# python

# %%
name.lstrip() # left  stripping
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# 'python'
